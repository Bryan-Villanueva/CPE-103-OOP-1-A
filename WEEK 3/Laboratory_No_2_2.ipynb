# %% [markdown]
# <a href="https://colab.research.google.com/github/Bryan-Villanueva/CPE-103-OOP-1-A/blob/main/Laboratory_No_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task**
#
#
# A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
# 1.	PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#
# 2.	PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
# 3.	MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#
# 4.	MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
# 5.	FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#
# 6.	FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
# 7.	HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
#
# 8.	Major exams are inputted out of 100%.
#
# 9.	Show the codes that successfully run the program.
#
# 10.	Provide comments or documentation strings for your program.

# %%
# Prelim

print("PRELIM GRADE")
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim Class Standing is:", "%.2f" % PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is:", "%.2f" % PG)
print("")

# Midterm

print("MIDTERM GRADE")
MHOA = float(input("Enter Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
print("Midterm Class Standing is:", "%.2f" % MCS)
MEX = float(input("Enter Midterm Exam grade: "))
MG = MEX*.5 + MCS*.5
print("Midterm Grade is:", "%.2f" % MG)
print("")

# final
print("FINAL")
FHOA = float(input("Enter Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
print("Final Class Standing is:", "%.2f" % FCS)
FEX = float(input("Enter Final Exam grade: "))
FG = FEX*.5 + FCS*.5
print("Final Grade is:", "%.2f" % FG)
print("")

general_average = (PG + MG + FG)/3
print("The General Average is" , "%.2f" % general_average)
# Out:
# PRELIM GRADE
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 100
# Enter Prelim Assignment grade: 100
# Prelim Class Standing is: 100.00
# Enter Prelim Exam grade: 100
# Prelim Grade is: 100.00
#
# MIDTERM GRADE
# Enter Hands-on Activity grade: 100
# Enter Midterm Quiz grade: 100
# Enter Midterm Assignment grade: 100
# Midterm Class Standing is: 100.00
# Enter Midterm Exam grade: 100
# Midterm Grade is: 100.00
#
# FINAL
# Enter Hands-on Activity grade: 100
# Enter Final Quiz grade: 100
# Enter Final Assignment grade: 100
# Final Class Standing is: 100.00
# Enter Final Exam grade: 100
# Final Grade is: 100.00
#
# The General Average is 100.00

# %% [markdown]
# **Supplementary Activity**
#
# 1.	Test 3 students from the program you created.
#
# 2.	The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.
#
# 3.	Convert the final grade into the UCCs numerical grade. Please refer to the grading system.

# %%
def get_grade_description(grade):
    if grade >= 99:
        return "Excellent"
    elif 90 <= grade < 99:
        return "Very Good"
    elif 80 <= grade < 90:
        return "Good"
    elif 70 <= grade < 80:
        return "Satisfactory"
    elif 60 <= grade < 70:
        return "Passing"
    elif 60 <= grade < 60:
        return "Failing"
    else:
        return "Failing"

def main():
  name = (input("Enter your name: "))
  print("")

  # Prelim

  print("PRELIM GRADE")
  PHOA = float(input("Enter Hands-on Activity grade: "))
  PQUIZ = float(input("Enter Prelim Quiz grade: "))
  PAS = float(input("Enter Prelim Assignment grade: "))
  PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
  print("Prelim Class Standing is:", "%.2f" % PCS)
  PEX = float(input("Enter Prelim Exam grade: "))
  PG = PEX*.5 + PCS*.5
  print("Prelim Grade is:", "%.2f" % PG)
  print("")

  # Midterm

  print("MIDTERM GRADE")
  MHOA = float(input("Enter Hands-on Activity grade: "))
  MQUIZ = float(input("Enter Midterm Quiz grade: "))
  MAS = float(input("Enter Midterm Assignment grade: "))
  MCS = MHOA*.5 + MQUIZ*.3 + MAS*.2
  print("Midterm Class Standing is:", "%.2f" % MCS)
  MEX = float(input("Enter Midterm Exam grade: "))
  MG = MEX*.5 + MCS*.5
  print("Midterm Grade is:", "%.2f" % MG)
  print("")

  # final
  print("FINAL")
  FHOA = float(input("Enter Hands-on Activity grade: "))
  FQUIZ = float(input("Enter Final Quiz grade: "))
  FAS = float(input("Enter Final Assignment grade: "))
  FCS = FHOA*.5 + FQUIZ*.3 + FAS*.2
  print("Final Class Standing is:", "%.2f" % FCS)
  FEX = float(input("Enter Final Exam grade: "))
  FG = FEX*.5 + FCS*.5
  print("Final Grade is:", "%.2f" % FG)
  print("")

  semester_grade = (PG + MG + FG)/3
  print("The Semester Grade (GWA) is" , "%.2f" % semester_grade)
  description = get_grade_description(semester_grade)
  print("Grade Description:", description)
  print("")

  while True:
      output = input("Type 'next' to proceed with another student or 'exit' to quit: ").strip().lower()
      print("")
      if output == 'next':
          main()
          break
      elif output == 'exit':
          print("Exiting program.")
          return
      else:
          print("Invalid input. Please type 'next' to proceed or 'exit' to quit.")
          print("")

main()
# Out:
# Enter your name: Jezreel Regondola
#
# PRELIM GRADE
# Enter Hands-on Activity grade: 87
# Enter Prelim Quiz grade: 87
# Enter Prelim Assignment grade: 98
# Prelim Class Standing is: 89.20
# Enter Prelim Exam grade: 67
# Prelim Grade is: 78.10
#
# MIDTERM GRADE
# Enter Hands-on Activity grade: 88
# Enter Midterm Quiz grade: 99
# Enter Midterm Assignment grade: 87
# Midterm Class Standing is: 91.10
# Enter Midterm Exam grade: 67
# Midterm Grade is: 79.05
#
# FINAL
# Enter Hands-on Activity grade: 87
# Enter Final Quiz grade: 98
# Enter Final Assignment grade: 88
# Final Class Standing is: 90.50
# Enter Final Exam grade: 76
# Final Grade is: 83.25
#
# The Semester Grade (GWA) is 80.13
# Grade Description: Good
#
# Type 'next' to proceed with another student or 'exit' to quit: next
#
# Enter your name: Justine Villacin
#
# PRELIM GRADE
# Enter Hands-on Activity grade: 99
# Enter Prelim Quiz grade: 98
# Enter Prelim Assignment grade: 97
# Prelim Class Standing is: 98.30
# Enter Prelim Exam grade: 98
# Prelim Grade is: 98.15
#
# MIDTERM GRADE
# Enter Hands-on Activity grade: 96
# Enter Midterm Quiz grade: 97
# Enter Midterm Assignment grade: 87
# Midterm Class Standing is: 94.50
# Enter Midterm Exam grade: 97
# Midterm Grade is: 95.75
#
# FINAL
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 87
# Enter Final Assignment grade: 96
# Final Class Standing is: 94.80
# Enter Final Exam grade: 94
# Final Grade is: 94.40
#
# The Semester Grade (GWA) is 96.10
# Grade Description: Very Good
#
# Type 'next' to proceed with another student or 'exit' to quit: next
#
# Enter your name: Jhustine Bron
#
# PRELIM GRADE
# Enter Hands-on Activity grade: 78
# Enter Prelim Quiz grade: 96
# Enter Prelim Assignment grade: 76
# Prelim Class Standing is: 83.00
# Enter Prelim Exam grade: 88
# Prelim Grade is: 85.50
#
# MIDTERM GRADE
# Enter Hands-on Activity grade: 98
# Enter Midterm Quiz grade: 90
# Enter Midterm Assignment grade: 76
# Midterm Class Standing is: 91.20
# Enter Midterm Exam grade: 87
# Midterm Grade is: 89.10
#
# FINAL
# Enter Hands-on Activity grade: 99
# Enter Final Quiz grade: 78
# Enter Final Assignment grade: 100
# Final Class Standing is: 92.90
# Enter Final Exam grade: 98
# Final Grade is: 95.45
#
# The Semester Grade (GWA) is 90.02
# Grade Description: Very Good
#
# Type 'next' to proceed with another student or 'exit' to quit: exit
#
# Exiting program.
